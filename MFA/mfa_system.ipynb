# %% [markdown]
# # MFA System
# This system is developed using flodym

# %% [markdown]
# ### Import packages

# %%
import flodym as fd

# %% [markdown]
# ### Definition of MFA components

# %%
# define dimensions
dimension_definitions = [
    fd.DimensionDefinition(letter='t', name='time', dtype=int),
    fd.DimensionDefinition(letter='c', name='carrier', dtype=str),
    fd.DimensionDefinition(letter='s', name='scenarios', dtype=str),
    fd.DimensionDefinition(letter='x', name='substance', dtype=str),
    fd.DimensionDefinition(letter='r', name='region', dtype=str),
    fd.DimensionDefinition(letter='g', name='technology', dtype=st),  
]

# define parameters
parameter_definitions = [
    fd.ParameterDefinition(name='', dim_letters=('',)),

]

# process definitions 
process_names = [ 
    'ind_ww',
    'dom_ww',
    'dec_tre',
    'sec_tre',
    'aop',
    'o3',
    'gac',
    'sldg_sep',
    'inc',
    'fer',
    'soi',
    'wtr_dis',
    'irr',
    'riv',
    'gro'
]

# flow definitions
flow_definitions = [
    fd.FlowDefinition(from_process_name='ind_ww', to_process_name='dec_tre', dim_letters=('x', 'r', 'g', 't')),
    fd
]

# %%
fd?
