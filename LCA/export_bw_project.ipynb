# %%
from premise import *
import bw2data as bd
import bw2io as bi
# Out:
# 09:45:30+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %%
bd.projects.set_current("paw_lca")

# %%
bd.databases
# Out:
# Databases dictionary with 9 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_remind-eu_SSP2-NPi_2035 2025-11-12
# 	ei_cutoff_3.11_remind-eu_SSP2-NPi_2045 2025-11-12
# 	ei_cutoff_3.11_remind-eu_SSP2-PkBudg1000_2035 2025-11-12
# 	ei_cutoff_3.11_remind-eu_SSP2-PkBudg1000_2045 2025-11-12
# 	ei_cutoff_3.11_remind-eu_SSP2-PkBudg650_2035 2025-11-12
# 	ei_cutoff_3.11_remind-eu_SSP2-PkBudg650_2045 2025-11-12
# 	paw_db

# %%
bi.backup_project_directory(bd.projects.current, dir_backup="C:/Users/welkerm/ecoinvent/", timestamp=True)
# Out:
# Creating project backup archive - this could take a few minutes...
# Saved to: C:\Users\welkerm\ecoinvent\brightway2-project-paw_lca-backup13-November-2025-09-50AM.tar.gz
# WindowsPath('C:/Users/welkerm/ecoinvent/brightway2-project-paw_lca-backup13-November-2025-09-50AM.tar.gz')
